# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("ev_final.xlsx")
data.head()
# Out:
#         uid                    name             vendor_name  \
# 0  STATIC12  GensolCharge Pvt. Ltd.  GensolCharge Pvt. Ltd.
# 1  STATIC14                    REIL                    REIL
# 2  STATIC15                    REIL                    REIL
# 3  STATIC16                    REIL                    REIL
# 4  STATIC17                BluSmart                BluSmart
#
#                                       address   latitude  longitude   city  \
# 0             NDSE Grid, BRPL South Extension  28.568238  77.219666  Delhi
# 1                       Scada office kalka ji  28.541995  77.260583  Delhi
# 2                   Ashram Chowk Mathura Road  28.571189  77.259806  Delhi
# 3                  Nizamuddin Railway station  28.588991  77.253240  Delhi
# 4  BSES Bhawan, Nehru Place, New Delhi 110048  28.549427  77.254636  Delhi
#
#   country      open     close  ... postal_code           zone   0 available  \
# 0   India  00:00:00  23:59:59  ...      110001  central-delhi NaN       NaN
# 1   India  00:00:00  23:59:59  ...      110001  central-delhi NaN       NaN
# 2   India  00:00:00  23:59:59  ...      110001  central-delhi NaN       NaN
# 3   India  00:00:00  23:59:59  ...      110001  central-delhi NaN       NaN
# 4   India  00:00:00  23:59:59  ...      110001  central-delhi NaN       NaN
#
#   capacity  cost_per_unit power_type  total         type        vehicle_type
# 0    15 kW            NaN         DC    2.0  BEVC DC 001              ['4W']
# 1   3.3 kW            NaN         AC    3.0  BEVC AC 001  ['2W', '3W', '4W']
# 2    15 kW            NaN         DC    2.0  BEVC DC 001              ['4W']
# 3    15 kW            NaN         DC    4.0  BEVC DC 001              ['4W']
# 4    15 kW            NaN         DC    1.0  BEVC DC 001              ['4W']
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (2705, 25)

# %%
data.describe().T
# Out:
#               count           mean            std  min            25%  \
# latitude     2705.0      27.021287       4.295497  0.0      28.535504
# longitude    2705.0      77.281839       3.884501  0.0      77.095390
# postal_code  2705.0  152660.247689  139469.046127  0.0  110032.000000
# 0               0.0            NaN            NaN  NaN            NaN
# available    2467.0       0.997973       1.626897  0.0       1.000000
# total        2497.0       1.221866       1.993488  1.0       1.000000
#
#                        50%            75%           max
# latitude         28.608759      28.674200  3.032503e+01
# longitude        77.195630      77.281573  8.851696e+01
# postal_code  110059.000000  110081.000000  1.100091e+06
# 0                      NaN            NaN           NaN
# available         1.000000       1.000000  7.300000e+01
# total             1.000000       1.000000  7.800000e+01

# %%
data.isnull().sum()
# Out:
# uid                   0
# name                  0
# vendor_name           0
# address               0
# latitude              0
# longitude             0
# city                  0
# country               0
# open                  0
# close                 0
# logo_url            467
# staff                 0
# payment_modes         0
# contact_numbers       0
# station_type          0
# postal_code           0
# zone                295
# 0                  2705
# available           238
# capacity            208
# cost_per_unit       252
# power_type          208
# total               208
# type                208
# vehicle_type        208
# dtype: int64

# %%
new_data=data.drop(columns=[0])

# %%
new_data.sample(5)
# Out:
#                    uid               name vendor_name  \
# 2472               890  EESL Metro Bhawan        EESL
# 33             EESL373               EESL        EESL
# 126           EESL1015               EESL        EESL
# 901   REVBOLT_00021139              REVOS       REVOS
# 1715  REVBOLT_00011595              REVOS       REVOS
#
#                                                 address   latitude  longitude  \
# 2472           Metro Bhawan, Nagpur ,Maharashtra 440010  21.129822  79.066354
# 33    NDMC Parking, Dharma Marg, Block Y, Diplomatic...  28.601809  77.186432
# 126   NDMC OUTSIDE, ESS 33/11KV NETAJI NAGAR DELHI-1...  28.579154  77.188127
# 901                                  nu 26A pitam pura   28.709471  77.141818
# 1715                          Igno Road Freedom Fighter  28.510612  77.200558
#
#            city country      open     close  ... station_type postal_code  \
# 2472     Nagpur   India     00:00     23:59  ...     charging      440010
# 33    New Delhi   India  00:00:00  23:59:59  ...     charging      110021
# 126   New Delhi   India  00:00:00  23:59:59  ...     charging      110003
# 901       Delhi   India  00:00:00  00:00:00  ...     charging      110034
# 1715  New Delhi   India  00:00:00  00:00:00  ...     charging      110030
#
#                   zone available  capacity    cost_per_unit power_type  total  \
# 2472               NaN       0.0  15.00 kW  ₹23.00 per unit         DC    2.0
# 33    south-west-delhi       2.0     15 kW     ₹10 per unit         DC    2.0
# 126      central-delhi       2.0     15 kW    ₹9.5 per unit         DC    2.0
# 901   north-west-delhi       1.0    3.3 kW      ₹0 per unit         AC    1.0
# 1715  south-west-delhi       1.0    3.3 kW      ₹0 per unit         AC    1.0
#
#                type  vehicle_type
# 2472         DC-001        ['4W']
# 33           DC-001        ['4W']
# 126          DC-001        ['4W']
# 901   5A/15A Socket  ['2W', '3W']
# 1715  5A/15A Socket  ['2W', '3W']
#
# [5 rows x 24 columns]

# %%
new_data.isnull().sum()
# Out:
# uid                  0
# name                 0
# vendor_name          0
# address              0
# latitude             0
# longitude            0
# city                 0
# country              0
# open                 0
# close                0
# logo_url           467
# staff                0
# payment_modes        0
# contact_numbers      0
# station_type         0
# postal_code          0
# zone               295
# available          238
# capacity           208
# cost_per_unit      252
# power_type         208
# total              208
# type               208
# vehicle_type       208
# dtype: int64

# %%
new_data['zone'].value_counts()
new_data['zone'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\3669738.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_data['zone'].fillna('Unknown', inplace=True)

# %%
new_data['available'].value_counts()
new_data['available'].fillna(new_data['available'].mode()[0],inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\738478719.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_data['available'].fillna(new_data['available'].mode()[0],inplace=True)

# %%
new_data.drop(columns=['uid','name','address','postal_code',],inplace=True)

# %%
new_data.drop(columns=['logo_url'],inplace=True)

# %%
new_data.drop(columns=['payment_modes','staff'],inplace=True)

# %%
india_data = new_data[(new_data['country'] == 'India') & (new_data['station_type'] == 'charging')]

# %%
india_data.drop(columns=['country','contact_numbers','station_type'],inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\806180618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data.drop(columns=['country','contact_numbers','station_type'],inplace=True)

# %%
india_data.shape
# Out:
# (2496, 14)

# %%
india_data.isnull().sum()
# Out:
# vendor_name       0
# latitude          0
# longitude         0
# city              0
# open              0
# close             0
# zone              0
# available         0
# capacity          1
# cost_per_unit    45
# power_type        1
# total             1
# type              1
# vehicle_type      1
# dtype: int64

# %%
india_data['capacity_num']=india_data['capacity'].str.extract(r'(\d+\.?\d*)')
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\2397655529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['capacity_num']=india_data['capacity'].str.extract(r'(\d+\.?\d*)')

# %%
india_data.drop(columns=['capacity'],inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\3114669674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data.drop(columns=['capacity'],inplace=True)

# %%
india_data['capacity_num']=pd.to_numeric(india_data['capacity_num'],errors='coerce',downcast='integer')
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\3344407643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['capacity_num']=pd.to_numeric(india_data['capacity_num'],errors='coerce',downcast='integer')

# %%
india_data['capacity_num'].describe()
# Out:
# count    2495.000000
# mean       19.728337
# std        42.020295
# min         3.300000
# 25%         3.300000
# 50%         3.300000
# 75%         3.300000
# max       142.000000
# Name: capacity_num, dtype: float64

# %%
india_data['capacity_num'].value_counts().get(142, 0)
# Out:
# 258

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(y=india_data['capacity_num'])
plt.show()

# %%
india_data
# Out:
#                  vendor_name   latitude  longitude       city      open  \
# 0     GensolCharge Pvt. Ltd.  28.568238  77.219666      Delhi  00:00:00
# 1                       REIL  28.541995  77.260583      Delhi  00:00:00
# 2                       REIL  28.571189  77.259806      Delhi  00:00:00
# 3                       REIL  28.588991  77.253240      Delhi  00:00:00
# 4                   BluSmart  28.549427  77.254636      Delhi  00:00:00
# ...                      ...        ...        ...        ...       ...
# 2700                    EESL  13.078481  80.249480    Chennai     00:00
# 2701                    EESL  13.078481  80.249480    Chennai     00:00
# 2702                    EESL  13.078481  80.249480    Chennai     00:00
# 2703           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
# 2704           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
#
#          close              zone  available    cost_per_unit power_type  \
# 0     23:59:59     central-delhi        1.0              NaN         DC
# 1     23:59:59     central-delhi        1.0              NaN         AC
# 2     23:59:59     central-delhi        1.0              NaN         DC
# 3     23:59:59     central-delhi        1.0              NaN         DC
# 4     23:59:59     central-delhi        1.0              NaN         DC
# ...        ...               ...        ...              ...        ...
# 2700     23:59           Unknown        0.0  ₹12.93 per unit         DC
# 2701     23:59           Unknown        0.0  ₹20.14 per unit         DC
# 2702     23:59           Unknown        0.0  ₹20.14 per unit         DC
# 2703  23:59:59  south-west-delhi        2.0     ₹16 per unit         AC
# 2704  23:59:59  south-west-delhi        2.0     ₹11 per unit         AC
#
#       total           type        vehicle_type  capacity_num
# 0       2.0    BEVC DC 001              ['4W']          15.0
# 1       3.0    BEVC AC 001  ['2W', '3W', '4W']           3.3
# 2       2.0    BEVC DC 001              ['4W']          15.0
# 3       4.0    BEVC DC 001              ['4W']          15.0
# 4       1.0    BEVC DC 001              ['4W']          15.0
# ...     ...            ...                 ...           ...
# 2700    1.0         DC-001              ['4W']          15.0
# 2701    2.0       CCS (DC)              ['4W']         142.0
# 2702    2.0   CHAdeMO (DC)              ['4W']         142.0
# 2703    2.0  TYPE - 2 (AC)              ['4W']           7.4
# 2704    2.0          AC001  ['2W', '3W', '4W']           3.3
#
# [2496 rows x 14 columns]

# %%
india_data['cpu_num']=india_data['cost_per_unit'].str.extract(r'(\d+\.?\d*)')
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\4235984922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['cpu_num']=india_data['cost_per_unit'].str.extract(r'(\d+\.?\d*)')

# %%
india_data.drop(columns=['cost_per_unit'],inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\3279290745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data.drop(columns=['cost_per_unit'],inplace=True)

# %%
india_data
# Out:
#                  vendor_name   latitude  longitude       city      open  \
# 0     GensolCharge Pvt. Ltd.  28.568238  77.219666      Delhi  00:00:00
# 1                       REIL  28.541995  77.260583      Delhi  00:00:00
# 2                       REIL  28.571189  77.259806      Delhi  00:00:00
# 3                       REIL  28.588991  77.253240      Delhi  00:00:00
# 4                   BluSmart  28.549427  77.254636      Delhi  00:00:00
# ...                      ...        ...        ...        ...       ...
# 2700                    EESL  13.078481  80.249480    Chennai     00:00
# 2701                    EESL  13.078481  80.249480    Chennai     00:00
# 2702                    EESL  13.078481  80.249480    Chennai     00:00
# 2703           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
# 2704           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
#
#          close              zone  available power_type  total           type  \
# 0     23:59:59     central-delhi        1.0         DC    2.0    BEVC DC 001
# 1     23:59:59     central-delhi        1.0         AC    3.0    BEVC AC 001
# 2     23:59:59     central-delhi        1.0         DC    2.0    BEVC DC 001
# 3     23:59:59     central-delhi        1.0         DC    4.0    BEVC DC 001
# 4     23:59:59     central-delhi        1.0         DC    1.0    BEVC DC 001
# ...        ...               ...        ...        ...    ...            ...
# 2700     23:59           Unknown        0.0         DC    1.0         DC-001
# 2701     23:59           Unknown        0.0         DC    2.0       CCS (DC)
# 2702     23:59           Unknown        0.0         DC    2.0   CHAdeMO (DC)
# 2703  23:59:59  south-west-delhi        2.0         AC    2.0  TYPE - 2 (AC)
# 2704  23:59:59  south-west-delhi        2.0         AC    2.0          AC001
#
#             vehicle_type  capacity_num cpu_num
# 0                 ['4W']          15.0     NaN
# 1     ['2W', '3W', '4W']           3.3     NaN
# 2                 ['4W']          15.0     NaN
# 3                 ['4W']          15.0     NaN
# 4                 ['4W']          15.0     NaN
# ...                  ...           ...     ...
# 2700              ['4W']          15.0   12.93
# 2701              ['4W']         142.0   20.14
# 2702              ['4W']         142.0   20.14
# 2703              ['4W']           7.4      16
# 2704  ['2W', '3W', '4W']           3.3      11
#
# [2496 rows x 14 columns]

# %%
india_data['cpu_num']=pd.to_numeric(india_data['cpu_num'],errors='coerce',downcast='integer')
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\508067439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['cpu_num']=pd.to_numeric(india_data['cpu_num'],errors='coerce',downcast='integer')

# %%
india_data['cpu_num'].fillna(6, inplace=True)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\1913637506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   india_data['cpu_num'].fillna(6, inplace=True)
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\1913637506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['cpu_num'].fillna(6, inplace=True)

# %%
india_data
# Out:
#                  vendor_name   latitude  longitude       city      open  \
# 0     GensolCharge Pvt. Ltd.  28.568238  77.219666      Delhi  00:00:00
# 1                       REIL  28.541995  77.260583      Delhi  00:00:00
# 2                       REIL  28.571189  77.259806      Delhi  00:00:00
# 3                       REIL  28.588991  77.253240      Delhi  00:00:00
# 4                   BluSmart  28.549427  77.254636      Delhi  00:00:00
# ...                      ...        ...        ...        ...       ...
# 2700                    EESL  13.078481  80.249480    Chennai     00:00
# 2701                    EESL  13.078481  80.249480    Chennai     00:00
# 2702                    EESL  13.078481  80.249480    Chennai     00:00
# 2703           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
# 2704           Verdemobility  28.572632  77.169680  New Delhi  00:00:00
#
#          close              zone  available power_type  total           type  \
# 0     23:59:59     central-delhi        1.0         DC    2.0    BEVC DC 001
# 1     23:59:59     central-delhi        1.0         AC    3.0    BEVC AC 001
# 2     23:59:59     central-delhi        1.0         DC    2.0    BEVC DC 001
# 3     23:59:59     central-delhi        1.0         DC    4.0    BEVC DC 001
# 4     23:59:59     central-delhi        1.0         DC    1.0    BEVC DC 001
# ...        ...               ...        ...        ...    ...            ...
# 2700     23:59           Unknown        0.0         DC    1.0         DC-001
# 2701     23:59           Unknown        0.0         DC    2.0       CCS (DC)
# 2702     23:59           Unknown        0.0         DC    2.0   CHAdeMO (DC)
# 2703  23:59:59  south-west-delhi        2.0         AC    2.0  TYPE - 2 (AC)
# 2704  23:59:59  south-west-delhi        2.0         AC    2.0          AC001
#
#             vehicle_type  capacity_num  cpu_num
# 0                 ['4W']          15.0     6.00
# 1     ['2W', '3W', '4W']           3.3     6.00
# 2                 ['4W']          15.0     6.00
# 3                 ['4W']          15.0     6.00
# 4                 ['4W']          15.0     6.00
# ...                  ...           ...      ...
# 2700              ['4W']          15.0    12.93
# 2701              ['4W']         142.0    20.14
# 2702              ['4W']         142.0    20.14
# 2703              ['4W']           7.4    16.00
# 2704  ['2W', '3W', '4W']           3.3    11.00
#
# [2496 rows x 14 columns]

# %%
(india_data['cpu_num']==0).sum()
# Out:
# 1821

# %%
india_data['cpu_num'] = india_data['cpu_num'].replace(0, 6)
# Out:
# C:\Users\RAJIB\AppData\Local\Temp\ipykernel_28032\1172541354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data['cpu_num'] = india_data['cpu_num'].replace(0, 6)

# %%
india_data['cpu_num'].describe()
# Out:
# count    2496.000000
# mean        8.541094
# std         6.096724
# min         1.600000
# 25%         6.000000
# 50%         6.000000
# 75%         6.000000
# max        33.000000
# Name: cpu_num, dtype: float64

# %%
india_data.sample(5)
# Out:
#      vendor_name   latitude  longitude       city      open     close  \
# 1644       REVOS  28.568917  77.186861  New Delhi  00:00:00  00:00:00
# 1343       REVOS  28.458800  77.184614  New Delhi  00:00:00  00:00:00
# 1957       REVOS  28.714123  77.130948  New Delhi  00:00:00  00:00:00
# 796        REVOS  28.502862  77.251506  New Delhi  00:00:00  00:00:00
# 1993       REVOS  28.500456  77.290362  New Delhi  00:00:00  00:00:00
#
#                   zone  available power_type  total           type  \
# 1644  south-west-delhi        1.0         AC    1.0  5A/15A Socket
# 1343  south-west-delhi        1.0         AC    1.0  5A/15A Socket
# 1957       north-delhi        1.0         AC    1.0  5A/15A Socket
# 796        south-delhi        1.0         AC    1.0  5A/15A Socket
# 1993       south-delhi        1.0         AC    1.0  5A/15A Socket
#
#       vehicle_type  capacity_num  cpu_num
# 1644  ['2W', '3W']           3.3      6.0
# 1343  ['2W', '3W']           3.3      6.0
# 1957  ['2W', '3W']           3.3      6.0
# 796   ['2W', '3W']           3.3      6.0
# 1993  ['2W', '3W']           3.3      6.0
